# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")
import seaborn as sns
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
#loading the data
df = pd.read_csv("./survey.csv")

# %%
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
#function for the bar plots
def bar_plot(categ_var):
    """
        input: variable ex: "anonymity"
        output: bar plot & value count
    """
    # get feature
    var = df[categ_var]
    # count number of categorical variable
    var_value = var.value_counts()
    
    plt.figure(figsize = (9,3))
    plt.bar(var_value.index, var_value)
    plt.xticks(var_value.index, var_value.values)
    plt.ylabel("Frequency")
    plt.title(categ_var)
    plt.show()
    print(f"{categ_var}:\n{var_value}")

# %%
#Investigate frequency of values for variable country
countries = ["Country"]
for c in countries:
    bar_plot(c)
# Out:
# Country:
# United States             751
# United Kingdom            185
# Canada                     72
# Germany                    45
# Ireland                    27
# Netherlands                27
# Australia                  21
# France                     13
# India                      10
# New Zealand                 8
# Poland                      7
# Switzerland                 7
# Sweden                      7
# Italy                       7
# South Africa                6
# Belgium                     6
# Brazil                      6
# Israel                      5
# Singapore                   4
# Bulgaria                    4
# Austria                     3
# Finland                     3
# Mexico                      3
# Russia                      3
# Denmark                     2
# Greece                      2
# Colombia                    2
# Croatia                     2
# Portugal                    2
# Moldova                     1
# ...

# %%
#keep countries that have 10 or more occurences in the observation
countries_to_keep = ['United States', 'United Kingdom','Canada','Germany','Netherlands','Ireland','Australia','France','India']
df = df[df.Country.isin(countries_to_keep ) == True]
df
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
# selected variables to be visualized
categorical_vars = ["Country","mental_vs_physical","family_history","treatment","seek_help","supervisor",
                    "mental_health_interview","coworkers","work_interfere","benefits","care_options","wellness_program",
                   "leave","mental_health_consequence"]
for c in categorical_vars:
    bar_plot(c)
# Out:
# Country:
# United States     751
# United Kingdom    185
# Canada             72
# Germany            45
# Netherlands        27
# Ireland            27
# Australia          21
# France             13
# India              10
# Name: Country, dtype: int64
# mental_vs_physical:
# Don't know    528
# Yes           321
# No            302
# Name: mental_vs_physical, dtype: int64
# family_history:
# No     691
# Yes    460
# Name: family_history, dtype: int64
# treatment:
# Yes    601
# No     550
# Name: treatment, dtype: int64
# seek_help:
# No            559
# Don't know    350
# Yes           242
# Name: seek_help, dtype: int64
# supervisor:
# Yes             474
# No              353
# Some of them    324
# Name: supervisor, dtype: int64
# mental_health_interview:
# No       931
# Maybe    183
# Yes       37
# Name: mental_health_interview, dtype: int64
# coworkers:
# Some of them    710
# No              235
# Yes             206
# Name: coworkers, dtype: int64
# work_interfere:
# ...

# %%
#Visualize the distribution of the geographic locations
sns.countplot(x='Country', data=df, palette='Set3')
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
#Loop through the selected variables and visualize how they vary by location
categorical_vars = ["mental_vs_physical","family_history","treatment","seek_help","supervisor",
                    "mental_health_interview","coworkers","work_interfere","benefits","care_options","wellness_program",
                   "leave","mental_health_consequence"]
for c in categorical_vars:
    sns.countplot(x=c,data=df,palette='Set3',hue='Country')
    plt.show()

# %%
#Discussion

# Thirteen variables were selected for proper analysis of mental health illness and attitude towards mental health based on heuristic 
# coupled with the questions and responses of the survey.

# The major problem encountered during the data analysis was 
# Identifying the right variables that describe attitude towards mental health

# United States have the highest frequecy for all the selected variables that was analyzed, next in the frequency value is United Kingdom,
# Canada ranks third in the frequency table.

# About 400 responses show that they have sought treatment for a mental health condition, while about 330 responses showed that they
# did not seek for treatment for a mental health condition in United States.

# Most of the responses in United States are not certain if their employer takes mental health as seriously as physical health, 
# however, it is somewhat evenly spread in other geographical locations.

# The dominant response for mental illness in family history for all the geographical locations is NO, as well as response to the question 
# of whether their employer provides resources to learn more about mental health issues and how to seek help.

# The analysis also show that employers do not discuss mental health as part of an employee program across all geographic locations.

# Lastly, majority of the responses show that they are unsure if discussing a mental health issue with their employer would have a
# negative consequence.
